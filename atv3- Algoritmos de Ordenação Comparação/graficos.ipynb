# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dt_media_tempo = pd.read_csv("tabelas\\media_tempo.csv")

# %%
sns.barplot(dt_media_tempo, x='media', y='algoritmo_linguagem')
plt.title("Média tempo de execursão")
# Out:
# Text(0.5, 1.0, 'Média tempo de execursão')

# %%
sns.scatterplot(dt_media_tempo, x='media', y='algoritmo_linguagem')
plt.title("Média tempo de execursão")
# Out:
# Text(0.5, 1.0, 'Média tempo de execursão')

# %%
dt_mediana_tempo = pd.read_csv("tabelas\\mediana_tempo.csv")

# %%
sns.barplot(dt_mediana_tempo, x='mediana', y='algoritmo_linguagem')
plt.title("Mediana do tempo de execursão")
# Out:
# Text(0.5, 1.0, 'Mediana do tempo de execursão')

# %%
sns.scatterplot(dt_mediana_tempo, x='mediana', y='algoritmo_linguagem')
plt.title("Mediana do tempo de execursão")
# Out:
# Text(0.5, 1.0, 'Mediana do tempo de execursão')

# %%
dt_media_memoria = pd.read_csv("tabelas\\media_memoria.csv")

# %%
sns.barplot(dt_media_memoria, x='media', y='algoritmo_linguagem')
plt.title("Média do uso do mamória")
# Out:
# Text(0.5, 1.0, 'Média do uso do mamória')

# %%
dt_mediana_memoria = pd.read_csv("tabelas\\mediana_memoria.csv")

# %%
sns.barplot(dt_mediana_memoria, x='mediana', y='algoritmo_linguagem')
plt.title("Mediana do uso de memória")
# Out:
# Text(0.5, 1.0, 'Mediana do uso de memória')
